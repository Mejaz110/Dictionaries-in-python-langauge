# %%
roll_numbers = {
    1:"001", 2:"002", 3:"003", 4:"004", 5:"005",
    6:"006", 7:"007", 8:"008", 9:"009", 10:"010"
}
names = {
    1:"Ali", 2:"Adil", 3:"Ahmed", 4:"Ejaz", 5:"Bilal",
    6:"Sajid", 7:"Usman", 8:"junaid", 9:"Baqir", 10:"Raheel"
}
marks = {
    1:15, 2:20, 3:30, 4:33, 5:40,
    6:10, 7:5, 8:17, 9:28, 10:39
}
print(names[1], marks[1],names[2],marks[2],names[3],marks[3],names[4],marks[4],names
[5],marks[5],names[6],marks[6],names[7],marks[7],names[8],marks[8],names[9],marks[9],names[10],marks[10])
# Out:
# Ali 15 Adil 20 Ahmed 30 Ejaz 33 Bilal 40 Sajid 10 Usman 5 junaid 17 Baqir 28 Raheel 39
